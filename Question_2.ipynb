# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
from sklearn.metrics import (confusion_matrix, accuracy_score)
from sklearn.preprocessing import OneHotEncoder
import statsmodels.api as sm
from sklearn.metrics import root_mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import confusion_matrix
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
insurance_df = pd.read_excel('insurance.xlsx')

# %%
# drop 'Seq nr' column
insurance_df = insurance_df.drop(['Seq nr'], axis=1)

# %%
insurance_df
# Out:
#           Group  age            job  marital  education default  balance  \
# 0      Training   30     management  married   tertiary      no     1119
# 1      Training   54     management  married   tertiary      no    -1415
# 2      Training   46         admin.   single    unknown     yes        0
# 3      Training   33     management  married   tertiary      no     2213
# 4      Training   52         admin.  married  secondary      no      484
# ...         ...  ...            ...      ...        ...     ...      ...
# 39995      Test   56  self-employed  married   tertiary     yes        0
# 39996      Test   27    blue-collar   single  secondary      no       87
# 39997      Test   30        retired   single  secondary      no       48
# 39998      Test   36    blue-collar  married  secondary      no     1797
# 39999      Test   46     technician  married   tertiary      no     -369
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# 0          no   no   cellular    6   aug       199         7     -1         0
# 1         yes  yes   cellular   17   nov       135         1     -1         0
# 2          no   no    unknown   23   may       378         2     -1         0
# 3          no   no   cellular   18   feb       240         1    385         9
# 4         yes   no    unknown    6   may       128         1     -1         0
# ...       ...  ...        ...  ...   ...       ...       ...    ...       ...
# 39995      no   no   cellular   19   nov       122         1     -1         0
# 39996      no   no  telephone   10   jul       245         1     -1         0
# 39997      no   no   cellular   18   may       142         2    300         1
# 39998     yes  yes   cellular   17   nov       166         1    181         2
# 39999     yes  yes   cellular    6   feb       339         4     -1         0
#
#       poutcome   y
# 0      unknown  no
# 1      unknown  no
# 2      unknown  no
# 3      failure  no
# 4      unknown  no
# ...        ...  ..
# 39995  unknown  no
# 39996  unknown  no
# 39997    other  no
# 39998  failure  no
# 39999  unknown  no
#
# [40000 rows x 18 columns]

# %%
# view counts of classes
insurance_df['y'].value_counts().to_dict()
# Out:
# {'no': 35330, 'yes': 4670}

# %%
# encode categorical features
X = insurance_df.drop(['y', 'Group'], axis=1)
X_encoded = pd.get_dummies(X, drop_first=True)
insurance_df_encoded = X_encoded
insurance_df_encoded['y'] = insurance_df['y']
insurance_df_encoded['Group'] = insurance_df['Group']

# %%
# split variables and create training and testing sets
train_df = insurance_df_encoded[insurance_df_encoded['Group'] == 'Training'].drop(['Group'], axis = 1)
test_df = insurance_df_encoded[insurance_df_encoded['Group'] == 'Test'].drop(['Group'], axis = 1)

X_train, X_test = train_df.drop(['y'], axis=1), test_df.drop(['y'], axis=1)
y_train, y_test = train_df['y'], test_df['y']

y_train_encoded = [1 if i == 'yes' else 0 for i in y_train]
y_test_encoded = [1 if i == 'yes' else 0 for i in y_test]

# %%
# view counts of classes in test set
test_df['y'].value_counts().to_dict()
# Out:
# {'no': 3540, 'yes': 460}

# %% [markdown]
# # Linear prediction model

# %%
# Initialize and fit model
X_train_with_constant = sm.add_constant(X_train)
mls_reg = sm.OLS(y_train_encoded, X_train_with_constant)
mls_res = mls_reg.fit()

# %%
# Get summary of model
print(mls_res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0
# month_aug           -7.400000e-02  7.000000e-03 -10.298  0.000 -8.800000e-02
# month_dec            1.211000e-01  2.200000e-02   5.485  0.000  7.800000e-02
# month_feb           -1.830000e-02  8.000000e-03  -2.168  0.030 -3.500000e-02
# month_jan           -1.098000e-01  1.000000e-02 -10.839  0.000 -1.300000e-01
# month_jul           -7.330000e-02  7.000000e-03 -10.638  0.000 -8.700000e-02
# month_jun            1.300000e-02  8.000000e-03   1.579  0.114 -3.000000e-03
# month_mar            2.914000e-01  1.500000e-02  19.539  0.000  2.620000e-01
# month_may           -3.150000e-02  7.000000e-03  -4.712  0.000 -4.500000e-02
# month_nov           -7.690000e-02  7.000000e-03 -10.320  0.000 -9.100000e-02
# month_oct            1.514000e-01  1.300000e-02  12.082  0.000  1.270000e-01
# month_sep            1.666000e-01  1.400000e-02  12.044  0.000  1.390000e-01
# poutcome_other       2.840000e-02  8.000000e-03   3.423  0.001  1.200000e-02
# poutcome_success     4.243000e-01  9.000000e-03  45.519  0.000  4.060000e-01
# poutcome_unknown    -1.350000e-02  9.000000e-03  -1.490  0.136 -3.100000e-02
#
#                        0.975]
# const                0.102000
# age                  0.000000
# balance              0.000002
# day                  0.001000
# duration             0.000000
# campaign            -0.001000
# pdays                0.000010
# previous             0.002000
# job_blue-collar     -0.009000
# job_entrepreneur    -0.006000
# job_housemaid       -0.018000
# job_management       0.003000
# job_retired          0.041000
# job_self-employed   -0.008000
# job_services         0.001000
# job_student          0.093000
# job_technician      -0.002000
# job_unemployed       0.009000
# job_unknown          0.020000
# marital_married     -0.005000
# marital_single       0.017000
# education_secondary  0.014000
# education_tertiary   0.035000
# education_unknown    0.027000
# default_yes          0.018000
# housing_yes         -0.042000
# loan_yes            -0.017000
# contact_telephone   -0.000019
# contact_unknown     -0.078000
# month_aug           -0.060000
# month_dec            0.164000
# month_feb           -0.002000
# month_jan           -0.090000
# month_jul           -0.060000
# month_jun            0.029000
# month_mar            0.321000
# month_may           -0.018000
# month_nov           -0.062000
# month_oct            0.176000
# month_sep            0.194000
# poutcome_other       0.045000
# poutcome_success     0.443000
# poutcome_unknown     0.004000

# %%
# view insignificant features
insignificant_features_mls = mls_results_as_df[mls_results_as_df['P>|t|'] > 0.05]
insignificant_features_mls
# Out:
#                              coef       std err      t  P>|t|        [0.025  \
# age                  2.000000e-04  0.000000e+00  0.867  0.386 -0.000000e+00
# balance              8.901000e-07  4.730000e-07  1.881  0.060 -3.720000e-08
# pdays               -4.931000e-05  3.050000e-05 -1.616  0.106 -0.000000e+00
# previous             7.000000e-04  1.000000e-03  0.985  0.325 -1.000000e-03
# job_management      -9.300000e-03  6.000000e-03 -1.542  0.123 -2.100000e-02
# job_services        -1.140000e-02  6.000000e-03 -1.808  0.071 -2.400000e-02
# job_unemployed      -9.700000e-03  9.000000e-03 -1.032  0.302 -2.800000e-02
# job_unknown         -1.670000e-02  1.900000e-02 -0.882  0.378 -5.400000e-02
# marital_single       6.300000e-03  5.000000e-03  1.188  0.235 -4.000000e-03
# education_secondary  5.200000e-03  5.000000e-03  1.140  0.254 -4.000000e-03
# education_unknown    1.140000e-02  8.000000e-03  1.408  0.159 -4.000000e-03
# default_yes         -2.400000e-03  1.100000e-02 -0.229  0.819 -2.300000e-02
# month_jun            1.300000e-02  8.000000e-03  1.579  0.114 -3.000000e-03
# poutcome_unknown    -1.350000e-02  9.000000e-03 -1.490  0.136 -3.100000e-02
#
#                        0.975]
# age                  0.000000
# balance              0.000002
# pdays                0.000010
# previous             0.002000
# job_management       0.003000
# job_services         0.001000
# job_unemployed       0.009000
# job_unknown          0.020000
# marital_single       0.017000
# education_secondary  0.014000
# education_unknown    0.027000
# default_yes          0.018000
# month_jun            0.029000
# poutcome_unknown     0.004000

# %%
# get latex syntax for implementation of table
#print(mls_res.summary().as_latex())

# %%
# Get predictions and metrics - classification view (accuracy, confusion matrix)
X_test_with_constant = sm.add_constant(X_test)
y_pred = mls_res.predict(X_test_with_constant)
y_pred_encoded = [1 if i >= 0.5 else 0 for i in y_pred]
tn, fp, fn, tp = confusion_matrix(y_test_encoded, y_pred_encoded).ravel()
specificity_mls = tn / (tn + fp)
sensitivity_ml = tp / (tp + fn)
accuracy_ml = (tp + tn) / (tp + tn + fp + fn)
print(f'specificity: {specificity_mls}' )
print(f'sensitivity: {sensitivity_ml}' )
print(f'accuracy: {accuracy_ml}' )
# Out:
# specificity: 0.976271186440678
# sensitivity: 0.3065217391304348
# accuracy: 0.89925

# %% [markdown]
# # Linear discriminant model (LDA)

# %%
# Initialize and fit model
lda_clf = LinearDiscriminantAnalysis()
lda_clf.fit(X_train, y_train)
# Out:
# LinearDiscriminantAnalysis()

# %%
# Get prediction and metrics
y_pred = lda_clf.predict(X_test)
tn,fp,fn,tp = confusion_matrix(y_test, y_pred).ravel()
specificity_lda = tn / (tn + fp)
sensitivity_lda = tp / (tp + fn)
accuracy_lda = (tp + tn) / (tp + tn + fp + fn)
print(f'specificity: {specificity_lda}' )
print(f'sensitivity: {sensitivity_lda}' )
print(f'accuracy: {accuracy_lda}' )
# Out:
# specificity: 0.9533898305084746
# sensitivity: 0.4369565217391304
# accuracy: 0.894

# %% [markdown]
# # Logistic regression model

# %%
# initialize and fit model
glm = sm.GLM(y_train_encoded,X_train_with_constant,family=sm.families.Binomial())
glm_res = glm.fit()

# %%
# Get summary of model
print(glm_res.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                36000
# Model:                            GLM   Df Residuals:                    35957
# Model Family:                Binomial   Df Model:                           42
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -8560.2
# Date:                Fri, 10 May 2024   Deviance:                       17120.
# Time:                        11:38:37   Pearson chi2:                 1.56e+07
# No. Iterations:                     7   Pseudo R-squ. (CS):             0.2181
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  -2.4892      0.205    -12.122      0.000      -2.892      -2.087
# age                 -3.142e-05      0.002     -0.013      0.990      -0.005       0.005
# balance               9.85e-06   5.86e-06      1.682      0.093   -1.63e-06    2.13e-05
# day                     0.0086      0.003      3.081      0.002       0.003       0.014
# duration                0.0042   7.28e-05     58.018      0.000       0.004       0.004
# campaign               -0.0889      0.011     -7.812      0.000      -0.111      -0.067
# pdays                3.467e-05      0.000      0.102      0.919      -0.001       0.001
# previous                0.0070      0.006      1.112      0.266      -0.005       0.019
# job_blue-collar        -0.3421      0.081     -4.202      0.000      -0.502      -0.183
# job_entrepreneur       -0.3822      0.141     -2.714      0.007      -0.658      -0.106
# job_housemaid          -0.5818      0.159     -3.664      0.000      -0.893      -0.271
# job_management         -0.1882      0.082     -2.306      0.021      -0.348      -0.028
# job_retired             0.2050      0.109      1.874      0.061      -0.009       0.419
# job_self-employed      -0.3687      0.127     -2.904      0.004      -0.618      -0.120
# job_services           -0.2089      0.094     -2.234      0.025      -0.392      -0.026
# job_student             0.3769      0.122      3.082      0.002       0.137       0.617
# job_technician         -0.2214      0.077     -2.870      0.004      -0.373      -0.070
# job_unemployed         -0.2282      0.126     -1.814      0.070      -0.475       0.018
# job_unknown            -0.2250      0.262     -0.858      0.391      -0.739       0.289
# marital_married        -0.2135      0.066     -3.248      0.001      -0.342      -0.085
# marital_single          0.0572      0.075      0.762      0.446      -0.090       0.204
# education_secondary     0.1615      0.073      2.203      0.028       0.018       0.305
# education_tertiary      0.3853      0.085      4.524      0.000       0.218       0.552
# education_unknown       0.2696      0.116      2.317      0.021       0.042       0.498
# default_yes            -0.0674      0.185     -0.364      0.716      -0.431       0.296
# housing_yes            -0.6664      0.049    -13.500      0.000      -0.763      -0.570
# loan_yes               -0.4395      0.068     -6.507      0.000      -0.572      -0.307
# contact_telephone      -0.1685      0.085     -1.989      0.047      -0.335      -0.002
# contact_unknown        -1.6123      0.082    -19.662      0.000      -1.773      -1.452
# month_aug              -0.7103      0.088     -8.064      0.000      -0.883      -0.538
# month_dec               0.6269      0.207      3.022      0.003       0.220       1.034
# month_feb              -0.1686      0.100     -1.686      0.092      -0.365       0.027
# month_jan              -1.2066      0.137     -8.832      0.000      -1.474      -0.939
# month_jul              -0.8217      0.087     -9.467      0.000      -0.992      -0.652
# month_jun               0.4332      0.106      4.081      0.000       0.225       0.641
# month_mar               1.6723      0.134     12.448      0.000       1.409       1.936
# month_may              -0.3652      0.080     -4.542      0.000      -0.523      -0.208
# month_nov              -0.8638      0.095     -9.112      0.000      -1.050      -0.678
# month_oct               0.8699      0.121      7.181      0.000       0.632       1.107
# month_sep               0.8987      0.133      6.756      0.000       0.638       1.159
# poutcome_other          0.2626      0.100      2.626      0.009       0.067       0.459
# poutcome_success        2.3395      0.092     25.328      0.000       2.158       2.521
# poutcome_unknown       -0.0675      0.104     -0.652      0.514      -0.271       0.135
# =======================================================================================

# %%
# convert results to pandas dataframe
glm_res_as_html = glm_res.summary().tables[1].as_html()
glm_res_as_df = pd.read_html(glm_res_as_html, header=0, index_col=0)[0]
glm_res_as_df
# Out:
#                          coef   std err       z  P>|z|    [0.025    0.975]
# const               -2.489200  0.205000 -12.122  0.000 -2.892000 -2.087000
# age                 -0.000031  0.002000  -0.013  0.990 -0.005000  0.005000
# balance              0.000010  0.000006   1.682  0.093 -0.000002  0.000021
# day                  0.008600  0.003000   3.081  0.002  0.003000  0.014000
# duration             0.004200  0.000073  58.018  0.000  0.004000  0.004000
# campaign            -0.088900  0.011000  -7.812  0.000 -0.111000 -0.067000
# pdays                0.000035  0.000000   0.102  0.919 -0.001000  0.001000
# previous             0.007000  0.006000   1.112  0.266 -0.005000  0.019000
# job_blue-collar     -0.342100  0.081000  -4.202  0.000 -0.502000 -0.183000
# job_entrepreneur    -0.382200  0.141000  -2.714  0.007 -0.658000 -0.106000
# job_housemaid       -0.581800  0.159000  -3.664  0.000 -0.893000 -0.271000
# job_management      -0.188200  0.082000  -2.306  0.021 -0.348000 -0.028000
# job_retired          0.205000  0.109000   1.874  0.061 -0.009000  0.419000
# job_self-employed   -0.368700  0.127000  -2.904  0.004 -0.618000 -0.120000
# job_services        -0.208900  0.094000  -2.234  0.025 -0.392000 -0.026000
# job_student          0.376900  0.122000   3.082  0.002  0.137000  0.617000
# job_technician      -0.221400  0.077000  -2.870  0.004 -0.373000 -0.070000
# job_unemployed      -0.228200  0.126000  -1.814  0.070 -0.475000  0.018000
# job_unknown         -0.225000  0.262000  -0.858  0.391 -0.739000  0.289000
# marital_married     -0.213500  0.066000  -3.248  0.001 -0.342000 -0.085000
# marital_single       0.057200  0.075000   0.762  0.446 -0.090000  0.204000
# education_secondary  0.161500  0.073000   2.203  0.028  0.018000  0.305000
# education_tertiary   0.385300  0.085000   4.524  0.000  0.218000  0.552000
# education_unknown    0.269600  0.116000   2.317  0.021  0.042000  0.498000
# default_yes         -0.067400  0.185000  -0.364  0.716 -0.431000  0.296000
# housing_yes         -0.666400  0.049000 -13.500  0.000 -0.763000 -0.570000
# loan_yes            -0.439500  0.068000  -6.507  0.000 -0.572000 -0.307000
# contact_telephone   -0.168500  0.085000  -1.989  0.047 -0.335000 -0.002000
# contact_unknown     -1.612300  0.082000 -19.662  0.000 -1.773000 -1.452000
# month_aug           -0.710300  0.088000  -8.064  0.000 -0.883000 -0.538000
# month_dec            0.626900  0.207000   3.022  0.003  0.220000  1.034000
# month_feb           -0.168600  0.100000  -1.686  0.092 -0.365000  0.027000
# month_jan           -1.206600  0.137000  -8.832  0.000 -1.474000 -0.939000
# month_jul           -0.821700  0.087000  -9.467  0.000 -0.992000 -0.652000
# month_jun            0.433200  0.106000   4.081  0.000  0.225000  0.641000
# month_mar            1.672300  0.134000  12.448  0.000  1.409000  1.936000
# month_may           -0.365200  0.080000  -4.542  0.000 -0.523000 -0.208000
# month_nov           -0.863800  0.095000  -9.112  0.000 -1.050000 -0.678000
# month_oct            0.869900  0.121000   7.181  0.000  0.632000  1.107000
# month_sep            0.898700  0.133000   6.756  0.000  0.638000  1.159000
# poutcome_other       0.262600  0.100000   2.626  0.009  0.067000  0.459000
# poutcome_success     2.339500  0.092000  25.328  0.000  2.158000  2.521000
# poutcome_unknown    -0.067500  0.104000  -0.652  0.514 -0.271000  0.135000

# %%
# view insignificant features
insignificant_features_glm = glm_res_as_df[glm_res_as_df['P>|z|'] > 0.05]
insignificant_features_glm
# Out:
#                       coef   std err      z  P>|z|    [0.025    0.975]
# age              -0.000031  0.002000 -0.013  0.990 -0.005000  0.005000
# balance           0.000010  0.000006  1.682  0.093 -0.000002  0.000021
# pdays             0.000035  0.000000  0.102  0.919 -0.001000  0.001000
# previous          0.007000  0.006000  1.112  0.266 -0.005000  0.019000
# job_retired       0.205000  0.109000  1.874  0.061 -0.009000  0.419000
# job_unemployed   -0.228200  0.126000 -1.814  0.070 -0.475000  0.018000
# job_unknown      -0.225000  0.262000 -0.858  0.391 -0.739000  0.289000
# marital_single    0.057200  0.075000  0.762  0.446 -0.090000  0.204000
# default_yes      -0.067400  0.185000 -0.364  0.716 -0.431000  0.296000
# month_feb        -0.168600  0.100000 -1.686  0.092 -0.365000  0.027000
# poutcome_unknown -0.067500  0.104000 -0.652  0.514 -0.271000  0.135000

# %%
# get latex syntax for implementation of table
#print(glm_res.summary().as_latex())

# %%
# Get prediction and metrics
y_pred = glm_res.predict(X_test_with_constant)
y_pred_encoded = [1 if i >= 0.5 else 0 for i in y_pred]
tn, fp, fn, tp = confusion_matrix(y_test_encoded, y_pred_encoded).ravel()
specificity_glm = tn / (tn + fp)
sensitivity_glm = tp / (tp + fn)
accuracy_glm = (tp + tn) / (tp + tn + fp + fn)
print(f'specificity: {specificity_glm}' )
print(f'sensitivity: {sensitivity_glm}' )
print(f'accuracy: {accuracy_glm}' )
# Out:
# specificity: 0.9697740112994351
# sensitivity: 0.35434782608695653
# accuracy: 0.899

# %% [markdown]
# # Model results

# %%
# create df of specificty, sensitivity and aacuracy
spec_list = [specificity_lda, specificity_mls, specificity_glm]
sens_list = [sensitivity_lda, sensitivity_ml, sensitivity_glm]
acc_list = [accuracy_lda, accuracy_ml, accuracy_glm]
model_list = ['Linear discriminant model', 'Linear prediction model', 'Logistic regression model'] 
df_results = pd.DataFrame(list(zip(model_list, spec_list, sens_list, acc_list)), 
                          columns=['Model', 'Specificity', 'Sensitivity', 'Accuracy'], index=None)

# %%
df_results
# Out:
#                        Model  Specificity  Sensitivity  Accuracy
# 0  Linear discriminant model     0.953390     0.436957   0.89400
# 1    Linear prediction model     0.976271     0.306522   0.89925
# 2  Logistic regression model     0.969774     0.354348   0.89900

# %%
# get latex code
print(df_results.to_latex())
# Out:
# \begin{tabular}{llrrr}
# \toprule
# {} &                      Model &  Specificity &  Sensitivity &  Accuracy \\
# \midrule
# 0 &  Linear discriminant model &     0.953390 &     0.436957 &   0.89400 \\
# 1 &    Linear prediction model &     0.976271 &     0.306522 &   0.89925 \\
# 2 &  Logistic regression model &     0.969774 &     0.354348 &   0.89900 \\
# \bottomrule
# \end{tabular}
# C:\Users\Armand\AppData\Local\Temp\ipykernel_3568\2402557598.py:2: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(df_results.to_latex())
